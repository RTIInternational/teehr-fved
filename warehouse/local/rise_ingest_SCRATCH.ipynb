# %%
import shutil
from pathlib import Path
import pandas as pd

from utils import rise_utils

# %% [markdown]
# ### assemble list of RISE crosswalk entries

# %%
# try formatting the rise location id's like 'rise-{location_id}-{record_id}-{item_id}'
test_locs = [
    'rise-392-2361-502', # DRGC2 in CBRFC
    'rise-491-2459-794', # TPIC2 in CBRFC
    'rise-453-2422-707', # OAWU1 in CBRFC
]

# %% [markdown]
# ### fetch timeseries data from RISE API

# %%
# test a single location
test_loc = test_locs[0]
df = rise_utils.fetch_timeseries(test_loc, start_date='2026-07-01')
print(df.shape)
print(df.head())

# %%
df
